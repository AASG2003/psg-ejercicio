# %%
#Code 01
print("hola mundo");
# Out:
# hola mundo

# %%
print("  *****  ")
print(" ******* ")
print("*********")
print(" ******* ")
print("*  ***  ")
print("   ***  ")
print("   ***  ")
print("~~~***~~~~~~~~~~")
# Out:
#   *****
#  *******
# *********
#  *******
# *  ***
#    ***
#    ***
# ~~~***~~~~~~~~~~

# %% [markdown]
# # Sesion 04
# - Mi primer notebook
# - Imprimir árbol
# - Crear Markdown
# - Subir a mi repositorio de GitHub
